# %%
import pandas as pd
import numpy as np

# %%
ny_data = pd.read_csv("NYC_dogs_clean.csv")
ny_data
# Out:
#         Unnamed: 0       X  RowNumber AnimalName AnimalGender  \
# 0                1       1       1753    SHADOW             M
# 1                2       2       2415      ROCCO            M
# 2                3       3       3328      LUIGI            M
# 3                4       4       7537    PETUNIA            F
# 4                5       5       8487      ROMEO            M
# ...            ...     ...        ...        ...          ...
# 121857      121928  121945     122225      ROCKY            M
# 121858      121929  121946     122226      ROXY             F
# 121859      121930  121947     122227  VALENTINA            F
# 121860      121931  121948     122228      VENUS            F
# 121861      121932  121949     122229     WILLOW            F
#
#               AnimalBirthMonth                   BreedName        Borough  \
# 0       01/01/2000 12:00:00 AM                      Beagle       Brooklyn
# ...

# %%
data = ny_data[ny_data.BreedName != "Unknown"]
data
# Out:
#         Unnamed: 0       X  RowNumber AnimalName AnimalGender  \
# 0                1       1       1753    SHADOW             M
# 1                2       2       2415      ROCCO            M
# 2                3       3       3328      LUIGI            M
# 3                4       4       7537    PETUNIA            F
# 4                5       5       8487      ROMEO            M
# ...            ...     ...        ...        ...          ...
# 121856      121927  121944     122224      ROCKO            M
# 121857      121928  121945     122225      ROCKY            M
# 121858      121929  121946     122226      ROXY             F
# 121859      121930  121947     122227  VALENTINA            F
# 121860      121931  121948     122228      VENUS            F
#
#               AnimalBirthMonth                   BreedName        Borough  \
# 0       01/01/2000 12:00:00 AM                      Beagle       Brooklyn
# ...

# %%
data = data.dropna()
data
# Out:
#         Unnamed: 0       X  RowNumber AnimalName AnimalGender  \
# 0                1       1       1753    SHADOW             M
# 1                2       2       2415      ROCCO            M
# 2                3       3       3328      LUIGI            M
# 3                4       4       7537    PETUNIA            F
# 4                5       5       8487      ROMEO            M
# ...            ...     ...        ...        ...          ...
# 121856      121927  121944     122224      ROCKO            M
# 121857      121928  121945     122225      ROCKY            M
# 121858      121929  121946     122226      ROXY             F
# 121859      121930  121947     122227  VALENTINA            F
# 121860      121931  121948     122228      VENUS            F
#
#               AnimalBirthMonth                   BreedName        Borough  \
# 0       01/01/2000 12:00:00 AM                      Beagle       Brooklyn
# ...

# %%
borough = data.value_counts("Borough")
borough
# Out:
# Borough
# Manhattan        36010
# Brooklyn         25505
# Queens           20714
# Bronx            10667
# Staten Island     9115
# dtype: int64

# %%
data = data.drop(['AnimalBirthMonth','CommunityDistrict', 
                  'NTA', 'CensusTract2010', 'CityCouncilDistrict', 
                  'CongressionalDistrict','StateSenatorialDistrict'], axis = 1)

# %%
data
# Out:
#         Unnamed: 0       X  RowNumber AnimalName AnimalGender  \
# 0                1       1       1753    SHADOW             M
# 1                2       2       2415      ROCCO            M
# 2                3       3       3328      LUIGI            M
# 3                4       4       7537    PETUNIA            F
# 4                5       5       8487      ROMEO            M
# ...            ...     ...        ...        ...          ...
# 121856      121927  121944     122224      ROCKO            M
# 121857      121928  121945     122225      ROCKY            M
# 121858      121929  121946     122226      ROXY             F
# 121859      121930  121947     122227  VALENTINA            F
# 121860      121931  121948     122228      VENUS            F
#
#                          BreedName        Borough  ZipCode LicenseIssuedDate  \
# 0                           Beagle       Brooklyn    11236        12/29/2014
# ...

# %%
data.to_csv("NYC_clean.csv")
