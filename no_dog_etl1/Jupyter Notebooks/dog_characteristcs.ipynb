# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\TriciaToffey\\desktop\\GitHubs\\ETL_Project\\no_dog_etl'

# %%
df_orig=pd.read_csv("./Resources/dog_breed_characteristics.csv")
df_orig.head(5)
# Out:
#              BreedName AltBreedName    Group1     Group2  MaleWtKg  \
# 0        Affenpinscher          NaN       Toy  Companion       4.0
# 1         Afghan Hound          NaN  Sporting      Sight      28.0
# 2  African Hunting Dog          NaN       NaN        NaN      23.0
# 3     Airedale Terrier     Airedale   Terrier    Terrier      26.0
# 4               Akbash          NaN   Working   Guardian      53.0
#
#                                           Temperment  AvgPupPrice  \
# 0  Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 1     Aloof, Clownish, Dignified, Happy, Independent       2250.0
# 2                                               Wild          NaN
# 3  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 4  Affectionate, Alert, Courageous, Independent, ...        600.0
#
#    Intelligence  Watchdog  MalaysiaGuardedDog  MalaysiaProhibitedDog  \
# 0          37.0       1.0                 NaN                    NaN
# 1          79.0       1.0                 NaN                    NaN
# 2           NaN       NaN                 NaN                    NaN
# 3          29.0       4.0                 NaN                    NaN
# 4           NaN       5.0                 NaN                    NaN
#
#    MalaysiaPopularity  PopularityUS2017
# 0                 NaN             147.0
# 1                 NaN              93.0
# 2                 NaN               NaN
# 3                 NaN              55.0
# 4                 NaN               NaN

# %%
df_orig.columns
# Out:
# Index(['BreedName', 'AltBreedName', 'Group1', 'Group2', 'MaleWtKg',
#        'Temperment', 'AvgPupPrice', 'Intelligence', 'Watchdog',
#        'MalaysiaGuardedDog', 'MalaysiaProhibitedDog', 'MalaysiaPopularity',
#        'PopularityUS2017'],
#       dtype='object')

# %%
df=df_orig.drop(["AltBreedName", "MalaysiaGuardedDog", "MalaysiaProhibitedDog", "MalaysiaPopularity"], axis=1)

# %%
df.head()
# Out:
#              BreedName    Group1     Group2  MaleWtKg  \
# 0        Affenpinscher       Toy  Companion       4.0
# 1         Afghan Hound  Sporting      Sight      28.0
# 2  African Hunting Dog       NaN        NaN      23.0
# 3     Airedale Terrier   Terrier    Terrier      26.0
# 4               Akbash   Working   Guardian      53.0
#
#                                           Temperment  AvgPupPrice  \
# 0  Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 1     Aloof, Clownish, Dignified, Happy, Independent       2250.0
# 2                                               Wild          NaN
# 3  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 4  Affectionate, Alert, Courageous, Independent, ...        600.0
#
#    Intelligence  Watchdog  PopularityUS2017
# 0          37.0       1.0             147.0
# 1          79.0       1.0              93.0
# 2           NaN       NaN               NaN
# 3          29.0       4.0              55.0
# 4           NaN       5.0               NaN

# %%
df.dropna(how='all')
# Out:
#                            BreedName        Group1     Group2  MaleWtKg  \
# 0                      Affenpinscher           Toy  Companion       4.0
# 1                       Afghan Hound      Sporting      Sight      28.0
# 2                African Hunting Dog           NaN        NaN      23.0
# 3                   Airedale Terrier       Terrier    Terrier      26.0
# 4                             Akbash       Working   Guardian      53.0
# ..                               ...           ...        ...       ...
# 245               Wirehaired Terrier       Terrier    Terrier       7.0
# 246  Xoloitzcuintle/Mexican Hairless  Non Sporting      Sight      11.0
# 247        Yellow Labrador Retriever      Sporting        Gun      32.0
# 248         Yorkshire Terrier Yorkie           Toy  Companion       3.0
# 249                      Mixed Breed           NaN        NaN       NaN
#
#                                             Temperment  AvgPupPrice  \
# 0    Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 1       Aloof, Clownish, Dignified, Happy, Independent       2250.0
# 2                                                 Wild          NaN
# 3    Alert, Confident, Courageous, Friendly, Intell...        700.0
# 4    Affectionate, Alert, Courageous, Independent, ...        600.0
# ..                                                 ...          ...
# 245  Alert, Bold, Fearless, Friendly, Keen, Quick, ...        900.0
# 246  Aleret, Calm, Cheerful, Companionable, Loyal, ...        700.0
# 247  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 248  Alert, Courageous, Energetic, Independent, Int...        800.0
# 249                                                NaN          NaN
#
#      Intelligence  Watchdog  PopularityUS2017
# 0            37.0       1.0             147.0
# 1            79.0       1.0              93.0
# 2             NaN       NaN               NaN
# 3            29.0       4.0              55.0
# 4             NaN       5.0               NaN
# ..            ...       ...               ...
# 245          51.0       3.0              99.0
# 246           NaN       3.0             143.0
# 247           7.0       3.0               1.0
# 248          27.0       3.0               9.0
# 249           NaN       NaN               NaN
#
# [250 rows x 9 columns]

# %%
df=df.rename(columns={'PopularityUS2017': 'breed_rank'})

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                         BreedName    Group1     Group2  MaleWtKg  \
# 0                   Affenpinscher       Toy  Companion       4.0
# 1                    Afghan Hound  Sporting      Sight      28.0
# 3                Airedale Terrier   Terrier    Terrier      26.0
# 5                           Akita   Working    Herding      44.0
# 6                Alaskan Malamute   Working   Northern      40.0
# ..                            ...       ...        ...       ...
# 243              Wire Fox Terrier   Terrier    Terrier       7.0
# 244  Wire-haired Pointing Griffon  Sporting        Gun      25.0
# 245            Wirehaired Terrier   Terrier    Terrier       7.0
# 247     Yellow Labrador Retriever  Sporting        Gun      32.0
# 248      Yorkshire Terrier Yorkie       Toy  Companion       3.0
#
#                                             Temperment  AvgPupPrice  \
# 0    Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 1       Aloof, Clownish, Dignified, Happy, Independent       2250.0
# 3    Alert, Confident, Courageous, Friendly, Intell...        700.0
# 5    Alert, Courageous, Dignified, Docile, Friendly...       1000.0
# 6    Affectionate, Devoted, Dignified, Friendly, Lo...       1350.0
# ..                                                 ...          ...
# 243  Alert, Bold, Fearless, Friendly, Keen, Quick, ...        900.0
# 244  Gentle, Loyal, Proud, Trainable, Vigilant, Int...        700.0
# 245  Alert, Bold, Fearless, Friendly, Keen, Quick, ...        900.0
# 247  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 248  Alert, Courageous, Energetic, Independent, Int...        800.0
#
#      Intelligence  Watchdog  breed_rank
# 0            37.0       1.0       147.0
# 1            79.0       1.0        93.0
# 3            29.0       4.0        55.0
# 5            54.0       5.0        47.0
# 6            50.0       5.0        59.0
# ..            ...       ...         ...
# 243          51.0       3.0        99.0
# 244          46.0       5.0        65.0
# 245          51.0       3.0        99.0
# 247           7.0       3.0         1.0
# 248          27.0       3.0         9.0
#
# [147 rows x 9 columns]

# %%
df['breed_rank'] = df['breed_rank'].astype(np.int64)

# %%
df=df.rename(columns={'Group1':'show_groups', 'Group2': 'subcategories', 'MaleWtKg': 'weight', 'Temperment': 'Temperament', "AvgPupPrice":"Average_Price", "Watchdog": "watchdog" })

# %%
#Characteristics_DF
characteristics_df = df
characteristics_df
characteristics_df.to_csv("characteristics_df.csv")

# %%
#df.sort_values(by=['PopularityUS2017']) -- no #189 in Characteristics

# %%
# df[['BreedName', 'PopularityUS2017']]

# %%
#df = df.loc[df['PopularityUS2017'].notnull()]

# %%
#duplicates = df["PopularityUS2017"].value_counts().loc[lambda x:x>1]

# %%
# duplicates =  df['PopularityUS2017'].value_counts().to_frame()
# duplicates=duplicates.reset_index()
# #duplicates.head(25)

# %%
# df_sorted = df.sort_values(by=["PopularityUS2017"])
# #df_sorted.tail(25)
# #There is no dog with PopularityUS2017 rank of 189

# %%
akc_df=pd.read_csv("index.csv")
#akc_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9d69d457653f> in <module>
# ----> 1 akc_df=pd.read_csv("index.csv")
#       2 #akc_df.head()
#
# NameError: name 'pd' is not defined

# %%
akc_df["Breed"].value_counts(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9a221b920151> in <module>
# ----> 1 akc_df["Breed"].value_counts(ascending=False)
#
# NameError: name 'akc_df' is not defined

# %%
# akc_df["Breed"]=akc_df["Breed"].map(lambda x: str(x) [:-1])

# %%
# akc_df
# Out:
#      breed_id                 Breed  breed_rank
# 0           1  Retrievers (Labrador           1
# 1           2   German Shepherd Dog           2
# 2           3    Retrievers (Golden           3
# 3           4        French Bulldog           4
# 4           5               Bulldog           5
# ..        ...                   ...         ...
# 185       186            Otterhound         186
# 186       187     American Foxhound         187
# 187       188               Sloughi         188
# 188       189      English Foxhound         189
# 189       190   Norwegian Lundehund         190
#
# [190 rows x 3 columns]

# %%
df["BreedName"].value_counts(ascending=False)
# Out:
# Boston Terrier          1
# Pug                     1
# Schnauzer               1
# Japanese Chin           1
# Scottish Deerhound      1
#                        ..
# Boxer                   1
# Bichon Frise            1
# Old English Sheepdog    1
# Brittany Spaniel        1
# Standard Poodle         1
# Name: BreedName, Length: 147, dtype: int64

# %%
pop_select=akc_df.loc[akc_df['breed_rank']==190]
pop_select
# Out:
#      breed_id                 Breed  breed_rank
# 189       190  Norwegian Lundehunds         190

# %%
# pop_select=df.loc[df['PopularityUS2017']==80]
# pop_select

# %%
# df.at[109,'BreedName']   #[row,column] -- Giant Schnauzer (Companion)
# df.at[202,'BreedName']   #[row,column] -- Giant Schnauzer (Herding)

# %%
# df.at[109,'BreedName']="Giant Schnauzer (Companion)"
# df.at[202,'BreedName']="Giant Schnauzer (Herding)"

# %%
# #df.at[109,'BreedName']   
# df.at[202,'BreedName']
# Out:
# 'Giant Schnauzer (Herding)'

# %%
merged_df=akc_df.merge(df, how="left", left_on="breed_rank", right_on="PopularityUS2017")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-4d408ccdd192> in <module>
# ----> 1 merged_df=akc_df.merge(df, how="left", left_on="breed_rank", right_on="PopularityUS2017")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7944         from pandas.core.reshape.merge import merge
#    7945
# -> 7946         return merge(
#    7947             self,
#    7948             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
#     654         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1003                     if not is_rkey(rk):
#    1004                         if rk is not None:
# -> 1005                             right_keys.append(right._get_label_or_level_values(rk))
#    1006                         else:
#    1007                             # work-around for merge_asof(right_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# -> 1563             raise KeyError(key)
#    1564
#    1565         # Check for duplicates
#
# KeyError: 'PopularityUS2017'

# %%
merged_df  #characteristics database is missing #189
# Out:
#      breed_id                  Breed  breed_rank  \
# 0           1  Retrievers (Labrador)           1
# 1           1  Retrievers (Labrador)           1
# 2           1  Retrievers (Labrador)           1
# 3           1  Retrievers (Labrador)           1
# 4           2   German Shepherd Dogs           2
# ..        ...                    ...         ...
# 211       187     American Foxhounds         187
# 212       187     American Foxhounds         187
# 213       188               Sloughis         188
# 214       189      English Foxhounds         189
# 215       190   Norwegian Lundehunds         190
#
#                         BreedName        Group1      Group2  MaleWtKg  \
# 0        Black Labrador Retriever      Sporting         Gun      32.0
# 1    Chocolate Labrador Retriever      Sporting         Gun      32.0
# 2              Labrador Retriever      Sporting         Gun      32.0
# 3       Yellow Labrador Retriever      Sporting         Gun      32.0
# 4             German Shepherd Dog       Herding     Herding      35.0
# ..                            ...           ...         ...       ...
# 211                      Foxhound         Hound  Scenthound      32.0
# 212                         Hound         Hound  Scenthound      32.0
# 213                       Sloughi         Hound       Sight      28.0
# 214             English Foxhounds           NaN         NaN       NaN
# 215           Norwegian Lundehund  Non Sporting    Northern       8.0
#
#                                             Temperment  AvgPupPrice  \
# 0    Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 1    Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 2    Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 3    Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 4    Alert, Confident, Courageous, Curious, Intelli...       1400.0
# ..                                                 ...          ...
# 211  Independent, Intelligent, Kind, Loving, Loyal,...        500.0
# 212  Independent, Intelligent, Kind, Loving, Loyal,...        500.0
# 213  Alert, Faithful, Intelligent, Sensitive, Indep...        900.0
# 214                                                NaN          NaN
# 215                Alert, Energetic, Loyal, Protective        500.0
#
#      Intelligence  Watchdog  PopularityUS2017
# 0             7.0       3.0               1.0
# 1             7.0       3.0               1.0
# 2             7.0       3.0               1.0
# 3             7.0       3.0               1.0
# 4             3.0       6.0               2.0
# ..            ...       ...               ...
# 211          46.0       2.0             187.0
# 212          46.0       2.0             187.0
# 213           NaN       5.0             188.0
# 214           NaN       NaN               NaN
# 215           NaN       4.0             190.0
#
# [216 rows x 12 columns]

# %%
merged_df.at[214,'BreedName']="English Foxhounds"

# %%
merged_df.isna().sum().sum()
# Out:
# 175

# %%
merged_df.drop(columns=['breed_id'])
# Out:
#                      Breed  breed_rank                     BreedName  \
# 0    Retrievers (Labrador)           1      Black Labrador Retriever
# 1    Retrievers (Labrador)           1  Chocolate Labrador Retriever
# 2    Retrievers (Labrador)           1            Labrador Retriever
# 3    Retrievers (Labrador)           1     Yellow Labrador Retriever
# 4     German Shepherd Dogs           2           German Shepherd Dog
# ..                     ...         ...                           ...
# 211     American Foxhounds         187                      Foxhound
# 212     American Foxhounds         187                         Hound
# 213               Sloughis         188                       Sloughi
# 214      English Foxhounds         189             English Foxhounds
# 215   Norwegian Lundehunds         190           Norwegian Lundehund
#
#            Group1      Group2  MaleWtKg  \
# 0        Sporting         Gun      32.0
# 1        Sporting         Gun      32.0
# 2        Sporting         Gun      32.0
# 3        Sporting         Gun      32.0
# 4         Herding     Herding      35.0
# ..            ...         ...       ...
# 211         Hound  Scenthound      32.0
# 212         Hound  Scenthound      32.0
# 213         Hound       Sight      28.0
# 214           NaN         NaN       NaN
# 215  Non Sporting    Northern       8.0
#
#                                             Temperment  AvgPupPrice  \
# 0    Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 1    Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 2    Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 3    Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 4    Alert, Confident, Courageous, Curious, Intelli...       1400.0
# ..                                                 ...          ...
# 211  Independent, Intelligent, Kind, Loving, Loyal,...        500.0
# 212  Independent, Intelligent, Kind, Loving, Loyal,...        500.0
# 213  Alert, Faithful, Intelligent, Sensitive, Indep...        900.0
# 214                                                NaN          NaN
# 215                Alert, Energetic, Loyal, Protective        500.0
#
#      Intelligence  Watchdog  PopularityUS2017
# 0             7.0       3.0               1.0
# 1             7.0       3.0               1.0
# 2             7.0       3.0               1.0
# 3             7.0       3.0               1.0
# 4             3.0       6.0               2.0
# ..            ...       ...               ...
# 211          46.0       2.0             187.0
# 212          46.0       2.0             187.0
# 213           NaN       5.0             188.0
# 214           NaN       NaN               NaN
# 215           NaN       4.0             190.0
#
# [216 rows x 11 columns]

# %%
akc_updated = pd.DataFrame(merged_df, columns = ['Breed','breed_rank'])

# %%
akc_updated.head()
# Out:
#                    Breed  breed_rank
# 0  Retrievers (Labrador)           1
# 1  Retrievers (Labrador)           1
# 2  Retrievers (Labrador)           1
# 3  Retrievers (Labrador)           1
# 4   German Shepherd Dogs           2

# %%
akc_updated.dtypes
# Out:
# Breed         object
# breed_rank     int64
# dtype: object

# %%
akc_updated.to_csv("akc_updated.csv")

# %%
df_updated = pd.DataFrame(merged_df, columns = ['BreedName', 'Group1', 'Group2', 'MaleWtKg','Temperment', 'AvgPupPrice', 'Intelligence', 'Watchdog'])

# %%
df_updated.head()
# Out:
#                       BreedName    Group1   Group2  MaleWtKg  \
# 0      Black Labrador Retriever  Sporting      Gun      32.0
# 1  Chocolate Labrador Retriever  Sporting      Gun      32.0
# 2            Labrador Retriever  Sporting      Gun      32.0
# 3     Yellow Labrador Retriever  Sporting      Gun      32.0
# 4           German Shepherd Dog   Herding  Herding      35.0
#
#                                           Temperment  AvgPupPrice  \
# 0  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 1  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 2  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 3  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 4  Alert, Confident, Courageous, Curious, Intelli...       1400.0
#
#    Intelligence  Watchdog
# 0           7.0       3.0
# 1           7.0       3.0
# 2           7.0       3.0
# 3           7.0       3.0
# 4           3.0       6.0

# %%
df_updated
# Out:
#                         BreedName        Group1      Group2  MaleWtKg  \
# 0        Black Labrador Retriever      Sporting         Gun      32.0
# 1    Chocolate Labrador Retriever      Sporting         Gun      32.0
# 2              Labrador Retriever      Sporting         Gun      32.0
# 3       Yellow Labrador Retriever      Sporting         Gun      32.0
# 4             German Shepherd Dog       Herding     Herding      35.0
# ..                            ...           ...         ...       ...
# 211                      Foxhound         Hound  Scenthound      32.0
# 212                         Hound         Hound  Scenthound      32.0
# 213                       Sloughi         Hound       Sight      28.0
# 214             English Foxhounds           NaN         NaN       NaN
# 215           Norwegian Lundehund  Non Sporting    Northern       8.0
#
#                                             Temperment  AvgPupPrice  \
# 0    Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 1    Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 2    Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 3    Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 4    Alert, Confident, Courageous, Curious, Intelli...       1400.0
# ..                                                 ...          ...
# 211  Independent, Intelligent, Kind, Loving, Loyal,...        500.0
# 212  Independent, Intelligent, Kind, Loving, Loyal,...        500.0
# 213  Alert, Faithful, Intelligent, Sensitive, Indep...        900.0
# 214                                                NaN          NaN
# 215                Alert, Energetic, Loyal, Protective        500.0
#
#      Intelligence  Watchdog
# 0             7.0       3.0
# 1             7.0       3.0
# 2             7.0       3.0
# 3             7.0       3.0
# 4             3.0       6.0
# ..            ...       ...
# 211          46.0       2.0
# 212          46.0       2.0
# 213           NaN       5.0
# 214           NaN       NaN
# 215           NaN       4.0
#
# [216 rows x 8 columns]

# %%
df_updated.to_csv("df_updated.csv")

# %%
nyc_df=pd.read_csv("./NYC_clean.csv")
nyc_df
# Out:
#         Unnamed: 0  Unnamed: 0.1       X  RowNumber AnimalName AnimalGender  \
# 0                0             1       1       1753    SHADOW             M
# 1                1             2       2       2415      ROCCO            M
# 2                2             3       3       3328      LUIGI            M
# 3                3             4       4       7537    PETUNIA            F
# 4                4             5       5       8487      ROMEO            M
# ...            ...           ...     ...        ...        ...          ...
# 102006      121856        121927  121944     122224      ROCKO            M
# 102007      121857        121928  121945     122225      ROCKY            M
# 102008      121858        121929  121946     122226      ROXY             F
# 102009      121859        121930  121947     122227  VALENTINA            F
# 102010      121860        121931  121948     122228      VENUS            F
#
#                          BreedName        Borough  ZipCode LicenseIssuedDate  \
# 0                           Beagle       Brooklyn    11236        12/29/2014
# 1                            Boxer       Brooklyn    11210        01/07/2015
# 2                          Maltese          Bronx    10464        01/17/2015
# 3                              Pug       Brooklyn    11221        03/01/2015
# 4                          Maltese          Bronx    10451        03/09/2015
# ...                            ...            ...      ...               ...
# 102006                   Chihuahua         Queens    11365        12/31/2016
# 102007              Boston Terrier      Manhattan    10022        12/31/2016
# 102008              Collie, Border       Brooklyn    11219        12/31/2016
# 102009  German Shepherd Crossbreed  Staten Island    10312        12/31/2016
# 102010           Yorkshire Terrier          Bronx    10455        12/31/2016
#
#        LicenseExpiredDate
# 0              01/30/2016
# 1              01/30/2016
# 2              02/02/2016
# 3              03/28/2016
# 4              03/09/2016
# ...                   ...
# 102006         12/31/2017
# 102007         12/31/2018
# 102008         09/18/2018
# 102009         12/31/2017
# 102010         06/06/2017
#
# [102011 rows x 11 columns]

# %%
nyc_df["BreedName"].value_counts()
# Out:
# Yorkshire Terrier          7479
# Shih Tzu                   6919
# Chihuahua                  5590
# Maltese                    4165
# Labrador Retriever         4099
#                            ...
# Norwegian Buhund              1
# Kai Ken                       1
# Afghan Hound Crossbreed       1
# Bracco Italiano               1
# Russian Wolfhound             1
# Name: BreedName, Length: 298, dtype: int64

# %%
# pop_select=df.loc[df['BreedName']=='Boxer']
# pop_select

# %%
#breed_select = nyc_df[nyc_df['Breed'].str.contains(r'(?!$)Shih')]
# breed_select["Breed"].value_counts()
# Out:
# Empty DataFrame
# Columns: [LicenseType, Breed, Color, DogName, OwnerZip, ExpYear, ValidDate]
# Index: []

# %%
merged_df=df.merge(nyc_df, how="left", on="BreedName" )

# %%
merged_df.head()
# Out:
#        BreedName Group1     Group2  MaleWtKg  \
# 0  Affenpinscher    Toy  Companion       4.0
# 1  Affenpinscher    Toy  Companion       4.0
# 2  Affenpinscher    Toy  Companion       4.0
# 3  Affenpinscher    Toy  Companion       4.0
# 4  Affenpinscher    Toy  Companion       4.0
#
#                                           Temperment  AvgPupPrice  \
# 0  Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 1  Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 2  Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 3  Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 4  Active, Adventurous, Curious, Fun-loving, Play...       1000.0
#
#    Intelligence  Watchdog  PopularityUS2017  Unnamed: 0  Unnamed: 0.1  \
# 0          37.0       1.0             147.0      3628.0        3631.0
# 1          37.0       1.0             147.0      5085.0        5091.0
# 2          37.0       1.0             147.0      7544.0        7554.0
# 3          37.0       1.0             147.0     15962.0       15978.0
# 4          37.0       1.0             147.0     19103.0       19122.0
#
#          X  RowNumber  AnimalName AnimalGender    Borough  ZipCode  \
# 0   3631.0     3504.0        OZZY            M  Manhattan  10038.0
# 1   5091.0     4967.0  CHEWBACCA             M  Manhattan  10065.0
# 2   7554.0     7430.0      DORADO            M  Manhattan  10038.0
# 3  15978.0    15862.0    EINSTEIN            M  Manhattan  10016.0
# 4  19122.0    19011.0     CHARLIE            F  Manhattan  10036.0
#
#   LicenseIssuedDate LicenseExpiredDate
# 0        01/19/2015         01/19/2016
# 1        02/04/2015         02/04/2017
# 2        02/27/2015         02/27/2016
# 3        05/04/2015         05/04/2016
# 4        05/29/2015         05/29/2016

# %%
merged_df.to_csv("merged_nyc.csv")

# %%
# for i, row in nyc_df.iterrows():
#     value = "Labrador Retriever"
#     if nyc_df.loc[i, "Breed"]=="Lab Mix":
#         nyc_df.at[i,'Breed'] = value

# %%
#nyc_df.drop(nyc_df[nyc_df['Breed'] == "Mixed"].index, inplace = True)

# %%
# top_counts = nyc_df["Breed"].value_counts().to_frame()

# %%
merged_nyc = nyc_df.merge(df, how="left", left_on="Breed", right_on="BreedName")
merged_nyc.head(50)
# Out:
#                                        LicenseType  \
# 0                     Dog Individual Spayed Female
# 1   Dog Senior Citizen or Disability Spayed Female
# 2                     Dog Individual Spayed Female
# 3                              Dog Individual Male
# 4                     Dog Individual Spayed Female
# 5   Dog Senior Citizen or Disability Neutered Male
# 6                            Dog Individual Female
# 7                     Dog Individual Spayed Female
# 8                     Dog Individual Spayed Female
# 9                     Dog Individual Spayed Female
# 10  Dog Senior Citizen or Disability Neutered Male
# 11  Dog Senior Citizen or Disability Neutered Male
# 12           Dog Senior Citizen or Disability Male
# 13      Dog Senior Citizen or Disability Duplicate
# 14                    Dog Individual Neutered Male
# 15                    Dog Individual Neutered Male
# 16  Dog Senior Citizen or Disability Neutered Male
# 17  Dog Senior Citizen or Disability Neutered Male
# 18  Dog Senior Citizen or Disability Spayed Female
# 19                    Dog Individual Neutered Male
# 20                    Dog Individual Neutered Male
# 21  Dog Senior Citizen or Disability Spayed Female
# 22                    Dog Individual Neutered Male
# 23                    Dog Individual Neutered Male
# 24  Dog Senior Citizen or Disability Neutered Male
# 25                    Dog Individual Neutered Male
# 26                    Dog Individual Neutered Male
# 27                    Dog Individual Spayed Female
# 28  Dog Senior Citizen or Disability Neutered Male
# 29           Dog Senior Citizen or Disability Male
# 30                    Dog Individual Spayed Female
# 31                    Dog Individual Spayed Female
# 32  Dog Senior Citizen or Disability Spayed Female
# 33  Dog Senior Citizen or Disability Spayed Female
# 34           Dog Senior Citizen or Disability Male
# 35  Dog Senior Citizen or Disability Spayed Female
# 36                             Dog Individual Male
# 37                    Dog Individual Spayed Female
# 38  Dog Senior Citizen or Disability Spayed Female
# 39         Dog Senior Citizen or Disability Female
# 40                    Dog Individual Spayed Female
# 41                    Dog Individual Neutered Male
# 42  Dog Senior Citizen or Disability Spayed Female
# 43  Dog Senior Citizen or Disability Spayed Female
# 44                    Dog Individual Neutered Male
# 45                    Dog Individual Neutered Male
# 46                    Dog Individual Neutered Male
# 47                    Dog Individual Neutered Male
# 48                           Dog Individual Female
# 49                    Dog Individual Neutered Male
#
#                                  Breed              Color      DogName  \
# 0                         Bichon Frise              WHITE        CHLOE
# 1                            Chihuahua  WHITE/BLACK/BROWN      CHALUPA
# 2                   Labrador Retriever             YELLOW          MIA
# 3                            Dachshund   BLACK/BROWN/GREY         CODY
# 4                            Dachshund              BLACK       SOPHIE
# 5                              Terrier            SPOTTED          MAX
# 6                              Terrier                TAN       SHELBY
# 7                              Terrier                TAN       SHELBY
# 8                  German Shepherd Dog          BLACK/TAN        ARWEN
# 9                            Schnoodle               GREY        RILEY
# 10                  Labrador Retriever              BLACK         LUKE
# 11                  Labrador Retriever              BLACK         LUKE
# 12                  Labrador Retriever              BLACK         LUKE
# 13                  Labrador Retriever              BLACK         LUKE
# 14                            Shih Tzu        BLACK/BROWN       TELLER
# 15                            Shih Tzu          WHITE/TAN         JACK
# 16                Old English Sheepdog         WHITE/GREY          MAX
# 17                             Maltese              WHITE       BAILEY
# 18                           Chihuahua          WHITE/TAN        ZEEBA
# 19                               Boxer        WHITE/BROWN        TYSON
# 20                     German Shepherd            BRINDLE        LUIGI
# 21                    Pit Bull Terrier        WHITE/BLACK          TIA
# 22                      Cocker Spaniel              BLACK       BUSTER
# 23            English Springer Spaniel            SPOTTED          MAX
# 24                        Bichon Frise              WHITE       BAILEY
# 25                              Beagle        BLACK/BROWN        LOUIE
# 26                    Golden Retriever               GOLD       TANNER
# 27                      Cocker Spaniel            SPOTTED         LEXI
# 28  West Highland White Terrier Westie              WHITE      CHARLIE
# 29                        Goldendoodle              BLACK  PEPE' LE PU
# 30                            Shih Tzu        WHITE/BLACK        BELLE
# 31                          Lhasa Apso        WHITE/BROWN       POOKIE
# 32                          Lhasa Apso        WHITE/BROWN       POOKIE
# 33                           Dachshund                RED         RUBY
# 34                  Labrador Retriever              BLACK     GRISWALD
# 35                 Parson Russell Terr        WHITE/BROWN       SKYLER
# 36                     Siberian Huskie        WHITE/BLACK        STORM
# 37                            Shih Tzu          WHITE/TAN       BONNIE
# 38                            Shih Tzu          WHITE/TAN       BONNIE
# 39                            Shih Tzu          WHITE/TAN       BONNIE
# 40                          Lhasa Apso              CREAM       MUFFIN
# 41                  Labrador Retriever             YELLOW         BUCK
# 42                 Parson Russell Terr            SPOTTED        MITZE
# 43                     German Shepherd        BLACK/BROWN        KAYLA
# 44                       Border Collie        WHITE/BLACK       FINNEY
# 45                  Labrador Retriever              BLACK         BEAR
# 46                          Lhasa Apso        WHITE/BROWN        BRADY
# 47                               Boxer  WHITE/BLACK/BROWN         LARS
# 48                       Border Collie        WHITE/BLACK        LACEY
# 49                    Brittany Spaniel              WHITE    MACKENZIE
#
#     OwnerZip  ExpYear         ValidDate                           BreedName  \
# 0      15090     2017   12/15/2016 9:58                        Bichon Frise
# 1      15120     2017   3/23/2017 14:32                           Chihuahua
# 2      15133     2017   2/28/2017 10:59                  Labrador Retriever
# 3      15108     2017    2/9/2017 13:40                           Dachshund
# 4      15108     2017    2/9/2017 13:40                           Dachshund
# 5      15228     2017    1/4/2017 15:49                             Terrier
# 6      15241     2017   12/15/2016 8:37                             Terrier
# 7      15241     2017   12/15/2016 8:37                             Terrier
# 8      15218     2017    1/3/2017 13:12                 German Shepherd Dog
# 9      15202     2017     1/4/2017 8:39                                 NaN
# 10     15014     2017               NaN                  Labrador Retriever
# 11     15014     2017               NaN                  Labrador Retriever
# 12     15014     2017  12/29/2016 12:14                  Labrador Retriever
# 13     15014     2017   3/20/2017 13:10                  Labrador Retriever
# 14     15146     2017   2/10/2017 13:32                            Shih Tzu
# 15     15146     2017   2/10/2017 13:32                            Shih Tzu
# 16     15129     2017  12/12/2016 11:09                Old English Sheepdog
# 17     15236     2017  12/15/2016 14:50                             Maltese
# 18     15025     2017  12/19/2016 15:13                           Chihuahua
# 19     15221     2017  12/20/2016 14:59                               Boxer
# 20     15017     2017   2/13/2017 15:02                                 NaN
# 21     15235     2017    2/8/2017 15:41                    Pit Bull Terrier
# 22     15024     2017   12/20/2016 8:44                      Cocker Spaniel
# 23     15122     2017               NaN            English Springer Spaniel
# 24     15146     2017  12/15/2016 16:01                        Bichon Frise
# 25     15239     2017    1/17/2017 9:11                              Beagle
# 26     15101     2017    1/4/2017 15:57                    Golden Retriever
# 27     15044     2017   12/12/2016 9:35                      Cocker Spaniel
# 28     15143     2017   12/12/2016 9:18  West Highland White Terrier Westie
# 29     15238     2017    1/9/2017 14:20                                 NaN
# 30     15065     2017     1/6/2017 9:24                            Shih Tzu
# 31     15137     2017   12/16/2016 8:40                          Lhasa Apso
# 32     15137     2017   12/16/2016 8:40                          Lhasa Apso
# 33     15216     2017  12/28/2016 16:31                           Dachshund
# 34     15148     2017  12/28/2016 16:31                  Labrador Retriever
# 35     15137     2017   12/14/2016 9:08                                 NaN
# 36     15122     2017    3/6/2017 13:54                                 NaN
# 37     15237     2017   12/22/2016 8:56                            Shih Tzu
# 38     15237     2017   12/22/2016 8:56                            Shih Tzu
# 39     15237     2017   1/24/2017 14:51                            Shih Tzu
# 40     15243     2017    1/5/2017 10:04                          Lhasa Apso
# 41     15101     2017  12/16/2016 16:25                  Labrador Retriever
# 42     15034     2017   3/22/2017 15:19                                 NaN
# 43     15120     2017  12/22/2016 16:28                                 NaN
# 44     15147     2017    1/5/2017 16:35                       Border Collie
# 45     15024     2017   1/17/2017 11:26                  Labrador Retriever
# 46     15065     2017  12/30/2016 11:15                          Lhasa Apso
# 47     15229     2017   12/12/2016 9:35                               Boxer
# 48     15146     2017   1/19/2017 15:56                       Border Collie
# 49     15126     2017  12/30/2016 15:41                    Brittany Spaniel
#
#           Group1      Group2  MaleWtKg  \
# 0   Non Sporting   Companion       4.0
# 1            Toy   Companion       2.0
# 2       Sporting         Gun      32.0
# 3          Hound  Scenthound       7.0
# 4          Hound  Scenthound       7.0
# 5        Terrier     Terrier       8.0
# 6        Terrier     Terrier       8.0
# 7        Terrier     Terrier       8.0
# 8        Herding     Herding      35.0
# 9            NaN         NaN       NaN
# 10      Sporting         Gun      32.0
# 11      Sporting         Gun      32.0
# 12      Sporting         Gun      32.0
# 13      Sporting         Gun      32.0
# 14           Toy   Companion       6.0
# 15           Toy   Companion       6.0
# 16       Herding     Herding      39.0
# 17           Toy   Companion       4.0
# 18           Toy   Companion       2.0
# 19       Working    Guardian      30.0
# 20           NaN         NaN       NaN
# 21       Terrier     Terrier      23.0
# 22      Sporting         Gun      10.0
# 23      Sporting         Gun      23.0
# 24  Non Sporting   Companion       4.0
# 25         Hound  Scenthound      11.0
# 26      Sporting         Gun      32.0
# 27      Sporting         Gun      10.0
# 28       Terrier     Terrier       8.0
# 29           NaN         NaN       NaN
# 30           Toy   Companion       6.0
# 31  Non Sporting   Companion       6.0
# 32  Non Sporting   Companion       6.0
# 33         Hound  Scenthound       7.0
# 34      Sporting         Gun      32.0
# 35           NaN         NaN       NaN
# 36           NaN         NaN       NaN
# 37           Toy   Companion       6.0
# 38           Toy   Companion       6.0
# 39           Toy   Companion       6.0
# 40  Non Sporting   Companion       6.0
# 41      Sporting         Gun      32.0
# 42           NaN         NaN       NaN
# 43           NaN         NaN       NaN
# 44       Herding     Herding      17.0
# 45      Sporting         Gun      32.0
# 46  Non Sporting   Companion       6.0
# 47       Working    Guardian      30.0
# 48       Herding     Herding      17.0
# 49      Sporting         Gun      17.0
#
#                                            Temperment  AvgPupPrice  \
# 0   Affectionate, Cheerful, Feisty, Gentle, Playfu...        850.0
# 1   Alert, Courageous, Devoted, Lively, Intelligen...        700.0
# 2   Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 3   Clever, Courageous, Devoted, Lively, Playful, ...        600.0
# 4   Clever, Courageous, Devoted, Lively, Playful, ...        600.0
# 5   Affectionate, Alert, Courageous, Intelligent, ...       1050.0
# 6   Affectionate, Alert, Courageous, Intelligent, ...       1050.0
# 7   Affectionate, Alert, Courageous, Intelligent, ...       1050.0
# 8   Alert, Confident, Courageous, Curious, Intelli...       1400.0
# 9                                                 NaN          NaN
# 10  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 11  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 12  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 13  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 14  Active, Courageous, Friendly, Gentle, Happy, I...       1000.0
# 15  Active, Courageous, Friendly, Gentle, Happy, I...       1000.0
# 16  Adaptable, Bubbly, Intelligent, Loving, Playfu...       1350.0
# 17  Active, Docile, Easygoing, Gentle, Intelligent...        700.0
# 18  Alert, Courageous, Devoted, Lively, Intelligen...        700.0
# 19  Brave, Bright, Confident, Energetic, Fearless,...        900.0
# 20                                                NaN          NaN
# 21  Affectionate, Aggressive, Clownish, Courageous...        600.0
# 22  Even Tempered, Joyful, Merry, Outgoing, Intell...        700.0
# 23  Affectionate, Alert, Cheerful, Energetic, Inte...        750.0
# 24  Affectionate, Cheerful, Feisty, Gentle, Playfu...        850.0
# 25  Friendly, Gentle, Independent, Intelligent, Li...        650.0
# 26  Confident, Friendly, Intelligent, Kind, Reliab...       1500.0
# 27  Even Tempered, Joyful, Merry, Outgoing, Intell...        700.0
# 28  Affectionate, Alert, Courageous, Intelligent, ...       1050.0
# 29                                                NaN          NaN
# 30  Active, Courageous, Friendly, Gentle, Happy, I...       1000.0
# 31  Alert, Assertive, Devoted, Friendly, Intellige...        600.0
# 32  Alert, Assertive, Devoted, Friendly, Intellige...        600.0
# 33  Clever, Courageous, Devoted, Lively, Playful, ...        600.0
# 34  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 35                                                NaN          NaN
# 36                                                NaN          NaN
# 37  Active, Courageous, Friendly, Gentle, Happy, I...       1000.0
# 38  Active, Courageous, Friendly, Gentle, Happy, I...       1000.0
# 39  Active, Courageous, Friendly, Gentle, Happy, I...       1000.0
# 40  Alert, Assertive, Devoted, Friendly, Intellige...        600.0
# 41  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 42                                                NaN          NaN
# 43                                                NaN          NaN
# 44  Intelligent, Energetic, Alert, Responsive, Ten...        700.0
# 45  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 46  Alert, Assertive, Devoted, Friendly, Intellige...        600.0
# 47  Brave, Bright, Confident, Energetic, Fearless,...        900.0
# 48  Intelligent, Energetic, Alert, Responsive, Ten...        700.0
# 49  Alert, Independent, Intelligent, Responsive, S...        750.0
#
#     Intelligence  Watchdog  PopularityUS2017
# 0           45.0       3.0              46.0
# 1           67.0       2.0              32.0
# 2            7.0       3.0               1.0
# 3           49.0       3.0              13.0
# 4           49.0       3.0              13.0
# 5           47.0       3.0              42.0
# 6           47.0       3.0              42.0
# 7           47.0       3.0              42.0
# 8            3.0       6.0               2.0
# 9            NaN       NaN               NaN
# 10           7.0       3.0               1.0
# 11           7.0       3.0               1.0
# 12           7.0       3.0               1.0
# 13           7.0       3.0               1.0
# 14          70.0       3.0              20.0
# 15          70.0       3.0              20.0
# 16          63.0       4.0              70.0
# 17          59.0       3.0              33.0
# 18          67.0       2.0              32.0
# 19          49.0       5.0              11.0
# 20           NaN       NaN               NaN
# 21           NaN       3.0               NaN
# 22          20.0       3.0              29.0
# 23          13.0       3.0              27.0
# 24          45.0       3.0              46.0
# 25          72.0       1.0               6.0
# 26           4.0       3.0               3.0
# 27          20.0       3.0              29.0
# 28          47.0       3.0              42.0
# 29           NaN       NaN               NaN
# 30          70.0       3.0              20.0
# 31          68.0       3.0              77.0
# 32          68.0       3.0              77.0
# 33          49.0       3.0              13.0
# 34           7.0       3.0               1.0
# 35           NaN       NaN               NaN
# 36           NaN       NaN               NaN
# 37          70.0       3.0              20.0
# 38          70.0       3.0              20.0
# 39          70.0       3.0              20.0
# 40          68.0       3.0              77.0
# 41           7.0       3.0               1.0
# 42           NaN       NaN               NaN
# 43           NaN       NaN               NaN
# 44           1.0       6.0              38.0
# 45           7.0       3.0               1.0
# 46          68.0       3.0              77.0
# 47          49.0       5.0              11.0
# 48           1.0       6.0              38.0
# 49          19.0       3.0              26.0

# %%
merged_nyc.isna().sum().sum()
# Out:
# 44143

# %%
nyc_breeds = merged_nyc['Breed'].value_counts().to_frame()
nyc_breeds
# Out:
#                     Breed
# Labrador Retriever   2573
# Beagle                965
# Pit Bull Terrier      836
# Chihuahua             830
# Shih Tzu              771
# ...                   ...
# Feist Treeing           1
# Cannan Dog              1
# Karelian Bear Dog       1
# Pumi                    1
# Polish Hound            1
#
# [253 rows x 1 columns]

# %% [raw]
# characteristics = df["BreedName'].value_counts().to_frame

# %%
merged_nyc["Breed"].value_counts()
# Out:
# Labrador Retriever    2573
# Beagle                 965
# Pit Bull Terrier       836
# Chihuahua              830
# Shih Tzu               771
#                       ...
# Feist Treeing            1
# Cannan Dog               1
# Karelian Bear Dog        1
# Pumi                     1
# Polish Hound             1
# Name: Breed, Length: 253, dtype: int64

# %%
merged_nyc.to_csv("nyc_merged.csv")

# %%
#df.loc[df.PopularityUS2017 == 68.0, 'BreedName'] = "Cardigan Welsh Corgis"
#Changed Welsh Corgi, Cardigan, Pembroke, Corgi to Cardigan Welsh Corgis

# %%
merged_df = df.merge(nyc_df, how="left", left_on="BreedName", right_on="Breed")
merged_df.head(50)
# Out:
#               BreedName    Group1     Group2  MaleWtKg  \
# 0         Affenpinscher       Toy  Companion       4.0
# 1         Affenpinscher       Toy  Companion       4.0
# 2         Affenpinscher       Toy  Companion       4.0
# 3         Affenpinscher       Toy  Companion       4.0
# 4          Afghan Hound  Sporting      Sight      28.0
# 5   African Hunting Dog       NaN        NaN      23.0
# 6      Airedale Terrier   Terrier    Terrier      26.0
# 7      Airedale Terrier   Terrier    Terrier      26.0
# 8      Airedale Terrier   Terrier    Terrier      26.0
# 9      Airedale Terrier   Terrier    Terrier      26.0
# 10     Airedale Terrier   Terrier    Terrier      26.0
# 11     Airedale Terrier   Terrier    Terrier      26.0
# 12     Airedale Terrier   Terrier    Terrier      26.0
# 13     Airedale Terrier   Terrier    Terrier      26.0
# 14     Airedale Terrier   Terrier    Terrier      26.0
# 15     Airedale Terrier   Terrier    Terrier      26.0
# 16     Airedale Terrier   Terrier    Terrier      26.0
# 17     Airedale Terrier   Terrier    Terrier      26.0
# 18     Airedale Terrier   Terrier    Terrier      26.0
# 19     Airedale Terrier   Terrier    Terrier      26.0
# 20     Airedale Terrier   Terrier    Terrier      26.0
# 21     Airedale Terrier   Terrier    Terrier      26.0
# 22     Airedale Terrier   Terrier    Terrier      26.0
# 23     Airedale Terrier   Terrier    Terrier      26.0
# 24     Airedale Terrier   Terrier    Terrier      26.0
# 25     Airedale Terrier   Terrier    Terrier      26.0
# 26     Airedale Terrier   Terrier    Terrier      26.0
# 27     Airedale Terrier   Terrier    Terrier      26.0
# 28     Airedale Terrier   Terrier    Terrier      26.0
# 29     Airedale Terrier   Terrier    Terrier      26.0
# 30     Airedale Terrier   Terrier    Terrier      26.0
# 31     Airedale Terrier   Terrier    Terrier      26.0
# 32     Airedale Terrier   Terrier    Terrier      26.0
# 33     Airedale Terrier   Terrier    Terrier      26.0
# 34     Airedale Terrier   Terrier    Terrier      26.0
# 35     Airedale Terrier   Terrier    Terrier      26.0
# 36     Airedale Terrier   Terrier    Terrier      26.0
# 37     Airedale Terrier   Terrier    Terrier      26.0
# 38     Airedale Terrier   Terrier    Terrier      26.0
# 39     Airedale Terrier   Terrier    Terrier      26.0
# 40     Airedale Terrier   Terrier    Terrier      26.0
# 41     Airedale Terrier   Terrier    Terrier      26.0
# 42               Akbash   Working   Guardian      53.0
# 43                Akita   Working    Herding      44.0
# 44                Akita   Working    Herding      44.0
# 45                Akita   Working    Herding      44.0
# 46                Akita   Working    Herding      44.0
# 47                Akita   Working    Herding      44.0
# 48                Akita   Working    Herding      44.0
# 49                Akita   Working    Herding      44.0
#
#                                            Temperment  AvgPupPrice  \
# 0   Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 1   Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 2   Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 3   Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 4      Aloof, Clownish, Dignified, Happy, Independent       2250.0
# 5                                                Wild          NaN
# 6   Alert, Confident, Courageous, Friendly, Intell...        700.0
# 7   Alert, Confident, Courageous, Friendly, Intell...        700.0
# 8   Alert, Confident, Courageous, Friendly, Intell...        700.0
# 9   Alert, Confident, Courageous, Friendly, Intell...        700.0
# 10  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 11  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 12  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 13  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 14  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 15  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 16  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 17  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 18  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 19  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 20  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 21  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 22  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 23  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 24  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 25  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 26  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 27  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 28  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 29  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 30  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 31  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 32  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 33  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 34  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 35  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 36  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 37  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 38  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 39  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 40  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 41  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 42  Affectionate, Alert, Courageous, Independent, ...        600.0
# 43  Alert, Courageous, Dignified, Docile, Friendly...       1000.0
# 44  Alert, Courageous, Dignified, Docile, Friendly...       1000.0
# 45  Alert, Courageous, Dignified, Docile, Friendly...       1000.0
# 46  Alert, Courageous, Dignified, Docile, Friendly...       1000.0
# 47  Alert, Courageous, Dignified, Docile, Friendly...       1000.0
# 48  Alert, Courageous, Dignified, Docile, Friendly...       1000.0
# 49  Alert, Courageous, Dignified, Docile, Friendly...       1000.0
#
#     Intelligence  Watchdog  PopularityUS2017  \
# 0           37.0       1.0             147.0
# 1           37.0       1.0             147.0
# 2           37.0       1.0             147.0
# 3           37.0       1.0             147.0
# 4           79.0       1.0              93.0
# 5            NaN       NaN               NaN
# 6           29.0       4.0              55.0
# 7           29.0       4.0              55.0
# 8           29.0       4.0              55.0
# 9           29.0       4.0              55.0
# 10          29.0       4.0              55.0
# 11          29.0       4.0              55.0
# 12          29.0       4.0              55.0
# 13          29.0       4.0              55.0
# 14          29.0       4.0              55.0
# 15          29.0       4.0              55.0
# 16          29.0       4.0              55.0
# 17          29.0       4.0              55.0
# 18          29.0       4.0              55.0
# 19          29.0       4.0              55.0
# 20          29.0       4.0              55.0
# 21          29.0       4.0              55.0
# 22          29.0       4.0              55.0
# 23          29.0       4.0              55.0
# 24          29.0       4.0              55.0
# 25          29.0       4.0              55.0
# 26          29.0       4.0              55.0
# 27          29.0       4.0              55.0
# 28          29.0       4.0              55.0
# 29          29.0       4.0              55.0
# 30          29.0       4.0              55.0
# 31          29.0       4.0              55.0
# 32          29.0       4.0              55.0
# 33          29.0       4.0              55.0
# 34          29.0       4.0              55.0
# 35          29.0       4.0              55.0
# 36          29.0       4.0              55.0
# 37          29.0       4.0              55.0
# 38          29.0       4.0              55.0
# 39          29.0       4.0              55.0
# 40          29.0       4.0              55.0
# 41          29.0       4.0              55.0
# 42           NaN       5.0               NaN
# 43          54.0       5.0              47.0
# 44          54.0       5.0              47.0
# 45          54.0       5.0              47.0
# 46          54.0       5.0              47.0
# 47          54.0       5.0              47.0
# 48          54.0       5.0              47.0
# 49          54.0       5.0              47.0
#
#                                        LicenseType             Breed  \
# 0                     Dog Individual Neutered Male     Affenpinscher
# 1   Dog Senior Citizen or Disability Neutered Male     Affenpinscher
# 2   Dog Senior Citizen or Disability Spayed Female     Affenpinscher
# 3                     Dog Individual Spayed Female     Affenpinscher
# 4                                              NaN               NaN
# 5                                              NaN               NaN
# 6   Dog Senior Citizen or Disability Spayed Female  Airedale Terrier
# 7                     Dog Individual Neutered Male  Airedale Terrier
# 8                     Dog Individual Spayed Female  Airedale Terrier
# 9   Dog Senior Citizen or Disability Neutered Male  Airedale Terrier
# 10                    Dog Individual Neutered Male  Airedale Terrier
# 11                    Dog Individual Neutered Male  Airedale Terrier
# 12  Dog Senior Citizen or Disability Neutered Male  Airedale Terrier
# 13                    Dog Individual Spayed Female  Airedale Terrier
# 14                    Dog Individual Spayed Female  Airedale Terrier
# 15  Dog Senior Citizen or Disability Neutered Male  Airedale Terrier
# 16                    Dog Individual Spayed Female  Airedale Terrier
# 17  Dog Senior Citizen or Disability Neutered Male  Airedale Terrier
# 18  Dog Senior Citizen or Disability Neutered Male  Airedale Terrier
# 19                    Dog Individual Neutered Male  Airedale Terrier
# 20  Dog Senior Citizen or Disability Spayed Female  Airedale Terrier
# 21                    Dog Individual Neutered Male  Airedale Terrier
# 22                    Dog Individual Spayed Female  Airedale Terrier
# 23  Dog Senior Citizen or Disability Neutered Male  Airedale Terrier
# 24                    Dog Individual Spayed Female  Airedale Terrier
# 25                    Dog Individual Neutered Male  Airedale Terrier
# 26  Dog Senior Citizen or Disability Neutered Male  Airedale Terrier
# 27  Dog Senior Citizen or Disability Neutered Male  Airedale Terrier
# 28  Dog Senior Citizen or Disability Spayed Female  Airedale Terrier
# 29                    Dog Individual Neutered Male  Airedale Terrier
# 30         Dog Senior Citizen or Disability Female  Airedale Terrier
# 31                    Dog Individual Spayed Female  Airedale Terrier
# 32                    Dog Individual Neutered Male  Airedale Terrier
# 33                    Dog Individual Neutered Male  Airedale Terrier
# 34                    Dog Individual Spayed Female  Airedale Terrier
# 35         Dog Senior Citizen or Disability Female  Airedale Terrier
# 36                    Dog Individual Neutered Male  Airedale Terrier
# 37           Dog Senior Citizen or Disability Male  Airedale Terrier
# 38                    Dog Individual Spayed Female  Airedale Terrier
# 39                           Dog Individual Female  Airedale Terrier
# 40                    Dog Individual Spayed Female  Airedale Terrier
# 41                    Dog Individual Spayed Female  Airedale Terrier
# 42                                             NaN               NaN
# 43  Dog Senior Citizen or Disability Neutered Male             Akita
# 44                    Dog Individual Neutered Male             Akita
# 45                    Dog Individual Spayed Female             Akita
# 46                    Dog Individual Spayed Female             Akita
# 47                    Dog Individual Spayed Female             Akita
# 48                    Dog Individual Spayed Female             Akita
# 49                    Dog Individual Spayed Female             Akita
#
#                 Color               DogName  OwnerZip  ExpYear  \
# 0               BLACK                 LUCKY   15239.0   2017.0
# 1               BLACK                CORBIN   15243.0   2017.0
# 2               BLACK                 EBONY   15228.0   2017.0
# 3               BLACK                PEPPER   15209.0   2017.0
# 4                 NaN                   NaN       NaN      NaN
# 5                 NaN                   NaN       NaN      NaN
# 6           BLACK/TAN                  LUCY   15135.0   2017.0
# 7         BLACK/BROWN               WINSTON   15237.0   2017.0
# 8           BLACK/TAN               JESSICA   15132.0   2017.0
# 9           BLACK/TAN                   ELI   15108.0   2017.0
# 10        BLACK/BROWN                GROVER   15015.0   2017.0
# 11              BLACK                 ROSCO   15139.0   2017.0
# 12        BLACK/BROWN                  ZEKE   15108.0   2017.0
# 13  WHITE/BLACK/BROWN                 CATIE   15044.0   2017.0
# 14        BLACK/BROWN                GRACIE   15209.0   2017.0
# 15          BLACK/TAN                  GINO   15229.0   2017.0
# 16          BLACK/TAN               MADISON   15237.0   2017.0
# 17          BLACK/TAN                HUDSON   15202.0   2017.0
# 18          BLACK/TAN               WINSTON   16046.0   2017.0
# 19        BLACK/BROWN               SHARKEY   15228.0   2017.0
# 20        BLACK/BROWN                 MADDY   15108.0   2017.0
# 21        BLACK/BROWN                TUCKER   15205.0   2017.0
# 22              BROWN                 IZZIE   15108.0   2017.0
# 23        BLACK/BROWN                 CHAOS   15209.0   2017.0
# 24          BLACK/TAN                  ZIVA   15131.0   2017.0
# 25          BLACK/TAN                   LEO   15102.0   2017.0
# 26          BLACK/TAN                 ABNER   15228.0   2017.0
# 27        BLACK/BROWN                 HARRY   15116.0   2017.0
# 28        BLACK/BROWN                 PENNY   15116.0   2017.0
# 29          BLACK/TAN                  REMY   15143.0   2017.0
# 30          BLACK/TAN  SHILLELAGH "LE-LAGH"   15106.0   2017.0
# 31        BLACK/BROWN                  ARYA   15101.0   2017.0
# 32        BLACK/BROWN            COSMO KING   15146.0   2017.0
# 33        BLACK/BROWN               WINSTON   15216.0   2017.0
# 34          BLACK/TAN                  ABBY   15131.0   2017.0
# 35              BROWN               CUDDLES   15037.0   2017.0
# 36              WHITE                SPARKY   15143.0   2017.0
# 37        BLACK/BROWN                HARLEY   15140.0   2017.0
# 38            SPOTTED                BONNIE   15145.0   2017.0
# 39        BLACK/BROWN      LUCKY PENNY LANE   15108.0   2017.0
# 40        BLACK/BROWN              ISABELLA   15143.0   2017.0
# 41        BLACK/BROWN                 CHLOE   15229.0   2017.0
# 42                NaN                   NaN       NaN      NaN
# 43        WHITE/BROWN          AMATSUMIKOTO   15215.0   2017.0
# 44        WHITE/BLACK                APOLLO   15202.0   2017.0
# 45        WHITE/BROWN                 AKARA   15142.0   2017.0
# 46        BLACK/BROWN              PRINCESS   15025.0   2017.0
# 47            SPOTTED                  MIKA   15065.0   2017.0
# 48              BLACK                MAKOTO   15143.0   2017.0
# 49              WHITE                 KARMA   15101.0   2017.0
#
#            ValidDate
# 0    2/27/2017 13:21
# 1   12/15/2016 11:27
# 2   12/13/2016 11:14
# 3    2/21/2017 12:06
# 4                NaN
# 5                NaN
# 6   12/27/2016 15:22
# 7   12/21/2016 10:51
# 8   12/13/2016 10:51
# 9     1/3/2017 16:34
# 10   1/10/2017 13:18
# 11     2/8/2017 9:10
# 12    1/3/2017 16:34
# 13   3/23/2017 14:32
# 14   1/24/2017 16:31
# 15   12/14/2016 9:08
# 16   1/23/2017 15:05
# 17   12/7/2016 16:19
# 18     1/4/2017 9:02
# 19   12/2/2016 13:28
# 20   3/20/2017 15:45
# 21   2/21/2017 12:09
# 22    2/7/2017 16:05
# 23    12/9/2016 8:58
# 24   12/7/2016 16:19
# 25    3/3/2017 14:14
# 26  12/29/2016 16:05
# 27    1/4/2017 15:56
# 28    1/4/2017 15:56
# 29  12/12/2016 15:33
# 30  12/19/2016 15:40
# 31   1/30/2017 14:21
# 32   1/25/2017 10:03
# 33  12/15/2016 10:16
# 34   12/7/2016 16:19
# 35     2/2/2017 9:43
# 36   1/19/2017 11:31
# 37  11/30/2016 14:06
# 38   12/2/2016 15:43
# 39   12/5/2016 16:05
# 40    1/27/2017 8:46
# 41   1/30/2017 13:52
# 42               NaN
# 43    2/22/2017 9:14
# 44     1/3/2017 8:58
# 45  12/14/2016 16:17
# 46   12/2/2016 13:28
# 47   1/25/2017 13:22
# 48   12/1/2016 16:07
# 49   3/27/2017 14:51

# %%
merged_df.isna().sum().sum()
# Out:
# 3639

# %%
null_df=merged_df[merged_df.isnull().any(axis=1)]

# %%
null_df
# Out:
#                              BreedName        Group1     Group2  MaleWtKg  \
# 4                         Afghan Hound      Sporting      Sight      28.0
# 5                  African Hunting Dog           NaN        NaN      23.0
# 42                              Akbash       Working   Guardian      53.0
# 75                    Alaskan Malamute       Working   Northern      40.0
# 76                    American Bulldog       Working   Guardian      38.0
# ...                                ...           ...        ...       ...
# 11551               Wirehaired Terrier       Terrier    Terrier       7.0
# 11552  Xoloitzcuintle/Mexican Hairless  Non Sporting      Sight      11.0
# 11553        Yellow Labrador Retriever      Sporting        Gun      32.0
# 11554         Yorkshire Terrier Yorkie           Toy  Companion       3.0
# 11555                      Mixed Breed           NaN        NaN       NaN
#
#                                               Temperment  AvgPupPrice  \
# 4         Aloof, Clownish, Dignified, Happy, Independent       2250.0
# 5                                                   Wild          NaN
# 42     Affectionate, Alert, Courageous, Independent, ...        600.0
# 75     Affectionate, Devoted, Dignified, Friendly, Lo...       1350.0
# 76     Affectionate, Alert, Courageous, Energetic, Ge...        800.0
# ...                                                  ...          ...
# 11551  Alert, Bold, Fearless, Friendly, Keen, Quick, ...        900.0
# 11552  Aleret, Calm, Cheerful, Companionable, Loyal, ...        700.0
# 11553  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 11554  Alert, Courageous, Energetic, Independent, Int...        800.0
# 11555                                                NaN          NaN
#
#        Intelligence  Watchdog  PopularityUS2017 LicenseType Breed Color  \
# 4              79.0       1.0              93.0         NaN   NaN   NaN
# 5               NaN       NaN               NaN         NaN   NaN   NaN
# 42              NaN       5.0               NaN         NaN   NaN   NaN
# 75             50.0       5.0              59.0         NaN   NaN   NaN
# 76              NaN       6.0               NaN         NaN   NaN   NaN
# ...             ...       ...               ...         ...   ...   ...
# 11551          51.0       3.0              99.0         NaN   NaN   NaN
# 11552           NaN       3.0             143.0         NaN   NaN   NaN
# 11553           7.0       3.0               1.0         NaN   NaN   NaN
# 11554          27.0       3.0               9.0         NaN   NaN   NaN
# 11555           NaN       NaN               NaN         NaN   NaN   NaN
#
#       DogName  OwnerZip  ExpYear ValidDate
# 4         NaN       NaN      NaN       NaN
# 5         NaN       NaN      NaN       NaN
# 42        NaN       NaN      NaN       NaN
# 75        NaN       NaN      NaN       NaN
# 76        NaN       NaN      NaN       NaN
# ...       ...       ...      ...       ...
# 11551     NaN       NaN      NaN       NaN
# 11552     NaN       NaN      NaN       NaN
# 11553     NaN       NaN      NaN       NaN
# 11554     NaN       NaN      NaN       NaN
# 11555     NaN       NaN      NaN       NaN
#
# [1723 rows x 16 columns]

# %%
merged_df["Breed"].value_counts()
# Out:
# Labrador Retriever     1379
# German Shepherd Dog     748
# Golden Retriever        694
# Shih Tzu                636
# Chihuahua               626
#                        ...
# Sussex Spaniel            1
# Kerry Blue Terrier        1
# Dingo                     1
# Carolina Dog              1
# Fila Brasileiro           1
# Name: Breed, Length: 109, dtype: int64
